# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
target = '/home/users/eeasm/_scripts/ICESat2/src/mpl/calibration/test.nc'
ds = xr.load_dataset(target)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                      (profile: 16, range: 999)
# Dimensions without coordinates: profile, range
# Data variables: (12/52)
#     unit                         (profile) float32 108.0 108.0 ... 108.0 108.0
#     version                      (profile) float32 413.0 413.0 ... 413.0 413.0
#     shots_sum                    (profile) float64 7.5e+04 7.5e+04 ... 7.5e+04
#     trigger_frequency            (profile) float64 2.5e+03 2.5e+03 ... 2.5e+03
#     energy_monitor               (profile) float64 5.181e+03 ... 5.225e+03
#     temp_0                       (profile) float64 1.565e+03 ... 1.566e+03
#     ...                           ...
#     channel_2                    (profile, range) float32 0.0002667 ... 0.000...
#     time_utc                     (profile) object '2018-12-20T14:16:34' ... '...
#     time                         (profile) datetime64[ns] 2018-12-20T14:16:34...
#     c                            float64 2.998e+08
# ...

# %%
ds.channel_1.plot(robust=True)

# %%
ds.channel_2.plot(robust=True)

# %%
fig, ax = plt.subplots(1,1)
ds.channel_1.mean(dim='profile').plot(yscale='log',ax=ax, label='channel 1')
ds.channel_2.mean(dim='profile').plot(yscale='log',ax=ax, label='channel 2', ylim=[0.0001,100])
ax.legend()
