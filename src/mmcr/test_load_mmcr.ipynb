# %% [markdown]
# # Testing the MMCR data format
#
# This notebook will be to test the data format that we load the MMCR data in as

# %%
# initial imports

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

from load_xarray_from_mmcrmom import load_xarray_from_mmcrmom

# %%
target = '/home/users/eeasm/_scripts/ICESat2/src/mmcr'
ds = load_xarray_from_mmcrmom(target)
ds
# Out:
# Files being loaded: ['20182021300MMCRMom.nc', '20182021400MMCRMom.nc']
# /home/users/eeasm/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/coding/variables.py:142: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/users/eeasm/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/coding/variables.py:142: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# <xarray.Dataset>
# Dimensions:                        (time: 4469, mode: 10, heights: 234)
# Dimensions without coordinates: time, mode, heights
# Data variables: (12/44)
#     base_time                      (time) datetime64[ns] 2018-07-21T13:00:00 ...
#     time_offset                    (time) datetime64[ns] 2018-07-21T00:00:00....
#     ModeDescription                (time, mode) object b'PR' b'ST' ... b'' b''
#     RxCalTimeStamp                 (time, mode) float64 1.53e+09 ... -2.147e+09
#     RxGain                         (time, mode) float32 176.1 ... 9.969e+36
#     SkyNoiseLevel                  (time, mode) float32 52.27 ... 9.969e+36
#     ...                             ...
#     SpectralWidth                  (time, heights) float32 0.3499 ... 9.969e+36
#     NoiseLevel                     (time, heights) float32 55.42 ... 9.969e+36
#     Reflectivity                   (time, heights) float32 -72.75 ... 9.969e+36
#     RangeCorrectedPower            (time, heights) float32 -109.0 ... 9.969e+36
#     CircularDepolarizationRatio    (time, heights) float32 9.969e+36 ... 9.96...
#     AvgNoiseLevel                  (time) float32 9.969e+36 ... 9.969e+36
# Attributes: (12/13)
#     site_id:                           Summit
#     facility_id:                       Summit
#     radar_operating_frequency:         34.86 GHz
#     radar_wavelength:                  8.600115e-003 m
#     peak_transmitted_power:            52.53 dBm
#     peak_transmitted_power_timestamp:  -1292815221 s
#     ...                                ...
#     twt_status_code:                   100000000
#     comment:                           DOE/ARM SGP MMCR netcdf raw file
#     resolution_description:            The resolution field attributes refer ...
#     proc_level:                        a1
#     history:                           created by LAP-XM
#     comment_on_time:                   The time stamp comes at the beginning ...

# %%
# plot the power
ds.where(ds.Power < 1e36).Power.plot(robust=True)
