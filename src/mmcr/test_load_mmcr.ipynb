# %% [markdown]
# # Testing the MMCR data format
#
# This notebook will be to test the data format that we load the MMCR data in as

# %%
# initial imports

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

from load_xarray_from_mmcrmom import *

# %%
target = '/home/users/eeasm/_scripts/ICESat2/src/mmcr'
ds = load_xarray_from_mmcrmom(target)
ds
# Out:
# Files being loaded: ['20190011000MMCRMom.nc', '20190011100MMCRMom.nc', '20190011200MMCRMom.nc', '20190011300MMCRMom.nc', '20190011400MMCRMom.nc', '20190011500MMCRMom.nc', '20190011600MMCRMom.nc', '20190011700MMCRMom.nc', '20190011800MMCRMom.nc', '20190011900MMCRMom.nc', '20190012000MMCRMom.nc', '20190012100MMCRMom.nc', '20190012200MMCRMom.nc', '20190012300MMCRMom.nc', '20190020000MMCRMom.nc', '20190010000MMCRMom.nc', '20190010100MMCRMom.nc', '20190010200MMCRMom.nc', '20190010300MMCRMom.nc', '20190010400MMCRMom.nc', '20190010500MMCRMom.nc', '20190010600MMCRMom.nc', '20190010700MMCRMom.nc', '20190010800MMCRMom.nc', '20190010900MMCRMom.nc']
# /home/users/eeasm/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/coding/variables.py:142: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# ...

# %%
# plot the power
ds.where(ds.Power < 1e36).Power.plot(robust=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # plot the power
# ----> 2 ds.where(ds.Power < 1e36).Power.plot(robust=True)
#
# File ~/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/core/common.py:1134, in DataWithCoords.where(self, cond, other, drop)
#    1131     self = self.isel(**indexers)
#    1132     cond = cond.isel(**indexers)
# -> 1134 return ops.where_method(self, cond, other)
#
# File ~/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/core/ops.py:177, in where_method(self, cond, other)
#     175 # alignment for three arguments is complicated, so don't support it yet
#     176 join = "inner" if other is dtypes.NA else "exact"
# --> 177 return apply_ufunc(
#     178     duck_array_ops.where_method,
#     179     self,
#     180     cond,
#     181     other,
#     182     join=join,
# ...

# %%
target = '/home/users/eeasm/_scripts/ICESat2/src/mmcr'
ds = read_radar_data(target,3,-10)
ds
# Out:
# /home/users/eeasm/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/coding/variables.py:142: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# <xarray.Dataset>
# Dimensions:                        (time: 6982, heights: 234)
# Dimensions without coordinates: time, heights
# Data variables: (12/44)
#     base_time                      (time, heights) datetime64[ns] dask.array<chunksize=(280, 234), meta=np.ndarray>
#     time_offset                    (time, heights) datetime64[ns] dask.array<chunksize=(280, 234), meta=np.ndarray>
#     ModeDescription                (time, heights) object dask.array<chunksize=(280, 234), meta=np.ndarray>
#     RxCalTimeStamp                 (time, heights) float64 dask.array<chunksize=(280, 234), meta=np.ndarray>
#     RxGain                         (time, heights) float32 dask.array<chunksize=(280, 234), meta=np.ndarray>
# ...

# %%
ds.ModeNum.plot(x='time')
# Out:
# /home/users/eeasm/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/coding/variables.py:142: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
ds.Heights.where(ds.Heights < 1e30).plot(x='time',robust=True)
# Out:
# /home/users/eeasm/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/coding/variables.py:142: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
#ds = ds.set_coords(['time_offset','Heights'])
ds.Reflectivity.where(ds.Reflectivity < 1e30).plot(x='time',robust=True)
#ds
# Out:
# /home/users/eeasm/.conda/envs/icesat_summit/lib/python3.10/site-packages/xarray/coding/variables.py:142: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
ds.heights.where(ds.heights < 1e30).plot()
